# %%
#Showing rules and guidance
print('Rules reminder: for two players, X and O, who take turns marking the spaces in a 3×3 grid.\nThe player who succeeds in placing three of their marks in a horizontal, vertical, or diagonal row is the winner.')

print('You will see the Board in a second.\nTo indicated the cell to which you want to move you need to type number from 1 to 9, corresponding to your choice.')

print("The cells numbers on the board are as follows:\n7, 8, 9\n4, 5, 6\n1, 2, 3")




#Defining the Board. Board contains empty spaces which will be replaced with players turn: 
board = {'7': ' ' , '8': ' ' , '9': ' ' ,
         '4': ' ' , '5': ' ' , '6': ' ' ,
         '1': ' ' , '2': ' ' , '3': ' ' }

#Separating the keys in the, it will be needed later for game restart
board_keys = []

for key in board:
    board_keys.append(key)

#Print Board. This function will be called after each turn to display updated board 
def print_board(board):
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('-+-+-')
    print(board['1'] + '|' + board['2'] + '|' + board['3'])
    
def move_check(prompt):
    while True:
        try:
            value = int(input(prompt))
        except ValueError:
            print("Invalid input. Try again.")
            continue
            
        if value > 9 or value < 1:
            print("Selected move is not in available range. Try again")
            continue
        else:
            move = str(value)
            break
    return move
        
# Game flow
def game():

    turn = 'X'
    count = 0
    player = 'Player_1'


    for i in range(9):
        print_board(ard)
        print("Now it's turn of:" + player + ' with ' + turn + " sign. To which position on the board do you want to move?") 
        
        move = move_check('Input')
    
        if board[move] == ' ':
            board[move] = turn
            count += 1
        else:
            print("That place is already filled.\nMove to which place?")
            continue
        
        
        # Winning combination will be achieved after 5 turns. So checking if player X or O has won,for every move after 5 moves for every winning combination. 
        # There are 8 winning combinations:
        if count >= 5:
            
            # across the top
            if board['7'] == board['8'] == board['9'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")                
                break
            # across the middle    
            elif board['4'] == board['5'] == board['6'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break
            # across the bottom    
            elif board['1'] == board['2'] == board['3'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break
            # down the left side    
            elif board['1'] == board['4'] == board['7'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break
            # down the middle    
            elif board['2'] == board['5'] == board['8'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break
            # down the right side    
            elif board['3'] == board['6'] == board['9'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break 
            # diagonal    
            elif board['7'] == board['5'] == board['3'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break
            # diagonal    
            elif board['1'] == board['5'] == board['9'] != ' ': 
                print_board(board)
                print("\nGame Over.\n")                
                print(" **** " + player + ' with ' +turn + " won. ****")
                break 

        # If neither X nor O wins and the board is full, declare the result as 'tie'
        if count == 9:
            print("\nGame Over.\n")                
            print("It's a Tie.")

        # Swap the players after every move:
        if turn =='X':
            turn = 'O'
            player = 'Player_1'
        else:
            turn = 'X'
            player = 'Player_2'
    
    # Check if player wants to play again
    restart = input("Do want to play Again?(y/n)")
    
    if restart.lower() == "y": 
        for key in board_keys:
            board[key] = " "
            game()
    else:
        print("You left the game.")

            
game()
# Out:
# Rules reminder: for two players, X and O, who take turns marking the spaces in a 3×3 grid.
# The player who succeeds in placing three of their marks in a horizontal, vertical, or diagonal row is the winner.
# You will see the Board in a second.
# To indicated the cell to which you want to move you need to type number from 1 to 9, corresponding to your choice.
# The cells numbers on the board are as follows:
# 7, 8, 9
# 4, 5, 6
# 1, 2, 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-79d654e1f29c> in <module>
#     143
#     144
# --> 145 game()
#
# <ipython-input-2-79d654e1f29c> in game()
#      53
#      54     for i in range(9):
# ---> 55         print_board(Board)
#      56         print("Now it's turn of:" + player + ' with ' + turn + " sign. To which position on the board do you want to move?")
#      57
#
# NameError: name 'Board' is not defined
